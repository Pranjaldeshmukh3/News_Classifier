# %% [markdown]
# # Welcome to Colab!
#
# ## Explore the Gemini API
# The Gemini API gives you access to Gemini models created by Google DeepMind. Gemini models are built from the ground up to be multimodal, so you can reason seamlessly across text, images, code, and audio.
#
# **How to get started?**
# *  Go to [Google AI Studio](https://aistudio.google.com/) and log in with your Google account.
# *  [Create an API key](https://aistudio.google.com/app/apikey).
# * Use a quickstart for [Python](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started.ipynb), or call the REST API using [curl](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/rest/Prompting_REST.ipynb).
#
# **Discover Gemini's advanced capabilities**
# *  Play with Gemini [multimodal outputs](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Image-out.ipynb), mixing text and images in an iterative way.
# *  Discover the [multimodal Live API](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_LiveAPI.ipynb ) (demo [here](https://aistudio.google.com/live)).
# *  Learn how to [analyze images and detect items in your pictures](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Spatial_understanding.ipynb") using Gemini (bonus, there's a [3D version](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Spatial_understanding_3d.ipynb) as well!).
# *  Unlock the power of [Gemini thinking model](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_thinking.ipynb), capable of solving complex task with its inner thoughts.
#
# **Explore complex use cases**
# *  Use [Gemini grounding capabilities](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Search_grounding_for_research_report.ipynb) to create a report on a company based on what the model can find on internet.
# *  Extract [invoices and form data from PDF](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Pdf_structured_outputs_on_invoices_and_forms.ipynb) in a structured way.
# *  Create [illustrations based on a whole book](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Book_illustration.ipynb) using Gemini large context window and Imagen.
#
# To learn more, check out the [Gemini cookbook](https://github.com/google-gemini/cookbook) or visit the [Gemini API documentation](https://ai.google.dev/docs/).

# %% [markdown]
# Colab now has AI features powered by [Gemini](https://gemini.google.com). The video below provides information on how to use these features, whether you're new to Python, or a seasoned veteran.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=V7RXyqFUR98" target="_blank">
#   <img alt='Thumbnail for a video showing 3 AI-powered Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) or [Colab Features You May Have Missed](https://www.youtube.com/watch?v=rNgswRZ2C1Y) to learn more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Getting started**
# </div>
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %% [markdown]
# Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.
#
# For example, if you find yourself waiting for **pandas** code to finish running and want to go faster, you can switch to a GPU Runtime and use libraries like [RAPIDS cuDF](https://rapids.ai/cudf-pandas) that provide zero-code-change acceleration.

# %% [markdown]
# To learn more about accelerating pandas on Colab, see the [10 minute guide](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_colab_demo.ipynb) or
#  [US stock market data analysis demo](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_stocks_demo.ipynb).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb).

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More Resources
#
# ### Working with Notebooks in Colab
#
# </div>
#
# - [Overview of Colab](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with Data
# </div>
#
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning
#
# <div>
#
# These are a few of the notebooks related to Machine Learning, including Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Intro to RAPIDS cuDF to accelerate pandas](https://nvda.ws/rapids-cudf)
# - [Getting Started with cuML's accelerator mode](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cuml_sklearn_colab_demo.ipynb)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# </div>
#
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TPUs in Colab](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.

# %%
# !pip install gensim

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

pd.set_option('display.max_colwidth', None)


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix

# NLP libraries
import gensim
import string
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer
from gensim.models import Word2Vec

# Warnings
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import files

# Upload file from your computer
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6595277c-2c2a-42fb-a419-e862bee28f47" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6595277c-2c2a-42fb-a419-e862bee28f47">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

original_data = pd.read_csv("bbc_news_text_complexity_summarization.csv")
original_data.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
# Dataset shape
print(f"The dataset has {original_data.shape[0]} rows and {original_data.shape[1]} columns.")

# Null values
print(f"The dataset has {original_data.isna().sum().sum()} null values.")

# Duplicate values
print(f"The dataset has {original_data.duplicated().sum()} duplicate values.")
# Out:
# The dataset has 2127 rows and 7 columns.
# The dataset has 0 null values.
# The dataset has 0 duplicate values.

# %%
# Drop duplicate rows in-place
original_data.drop_duplicates(inplace=True)

# Check the new shape of the DataFrame
original_data.shape
# Out:
# (2127, 7)

# %%
from google.colab import files

# Upload the CSV
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7d3214e9-7cba-49e0-8cd3-ca22ccfa3a9a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7d3214e9-7cba-49e0-8cd3-ca22ccfa3a9a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Load the dataset (correct the file path)
data_summary = pd.read_csv("bbc_news_text_complexity_summarization (2).csv")

# Show first 2 rows
data_summary.head(2)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
# Plot the distribution
sns.histplot(data=original_data, x="labels", kde=False)

# Add plot titles and labels
plt.title('Distribution of Target Classes', fontsize=25)
plt.xlabel('Target Classes', fontsize=15)
plt.ylabel('Count', fontsize=15)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# --- Top figure ---
fig, axes = plt.subplots(ncols=5, figsize=(20, 5))

# Word counts by category
categories = ['sport', 'business', 'politics', 'entertainment', 'tech']
colors = ['red', 'orange', 'yellow', 'green', 'blue']

for i, category in enumerate(categories):
    word_lengths = data_summary[data_summary['labels'] == category]['text'].str.split().map(len)
    axes[i].hist(word_lengths, color=colors[i], edgecolor="black", linewidth=1.2)
    axes[i].set_title(f'{category} articles', size=12)
    axes[i].set_xlabel('No. of words', size=10)
    axes[i].set_ylabel('Count', size=10)

plt.suptitle("No. of Words in BBC Articles", size=20)
plt.tight_layout()
plt.show()


# --- Central figure ---
fig, axes = plt.subplots(ncols=5, figsize=(20, 5))

for i, category in enumerate(categories):
    char_lengths = data_summary[data_summary['labels'] == category]['text'].str.split().apply(lambda x: [len(word) for word in x])
    avg_word_lengths = char_lengths.map(np.mean)
    sns.histplot(avg_word_lengths, ax=axes[i], kde=True, color=colors[i])
    axes[i].set_title(f'{category} articles', size=12)

plt.suptitle("Average Word Length in BBC Articles", size=20)
plt.tight_layout()
plt.show()


# --- Bottom figure ---
fig, axes = plt.subplots(ncols=2, figsize=(15, 6))

# Assuming you have a 'no_sentences' column already computed
avg_sentences = data_summary.groupby('labels')['no_sentences'].mean().reset_index()

# Bar plot of average no. of sentences
axes[0].bar(avg_sentences['labels'], avg_sentences['no_sentences'],
            color=colors, edgecolor="black")
axes[0].set_xlabel('Article Class', size=12)
axes[0].set_ylabel('Average No. of Sentences', size=12)
axes[0].set_title('Average Number of Sentences in BBC Articles', fontsize=14)

# Boxplot of sentence counts
grouped = data_summary.groupby("labels")["no_sentences"]
axes[1].boxplot([group.values for name, group in grouped],
                labels=grouped.groups.keys())
axes[1].set_xlabel('Article Class', size=12)
axes[1].set_ylabel('Number of Sentences', size=12)
axes[1].set_title('Sentence Count Boxplots', fontsize=14)

plt.suptitle("No. of Sentences in BBC Articles", size=20)
plt.tight_layout()
plt.show()

# %%
print(f"Mean no. of words in sport articles: {wd_len_sp.mean():.1f}")
print(f"Mean no. of words in business articles: {wd_len_bus.mean():.1f}")
print(f"Mean no. of words in politics articles: {wd_len_pol.mean():.1f}")
print(f"Mean no. of words in entertainment articles: {wd_len_ent.mean():.1f}")
print(f"Mean no. of words in tech articles: {wd_len_te.mean():.1f}")
# Out:
# Mean no. of words in sport articles: 330.6
# Mean no. of words in business articles: 328.7
# Mean no. of words in politics articles: 456.2
# Mean no. of words in entertainment articles: 332.7
# Mean no. of words in tech articles: 513.2

# %%
# Compute Mean Readability Scores
Dale_Chall = (
    data_summary.groupby('labels')['Dale-Chall Readability Score'].mean()
    .reset_index()
    .rename(columns={'Dale-Chall Readability Score': 'Mean Dale-Chall Readability Score'})
    .sort_values(by='Mean Dale-Chall Readability Score', ascending=False)
)

Flesch = (
    data_summary.groupby('labels')['Flesch Reading Ease Score'].mean()
    .reset_index()
    .rename(columns={'Flesch Reading Ease Score': 'Mean Flesch Reading Ease Score'})
    .sort_values(by='Mean Flesch Reading Ease Score', ascending=False)
)

# Create Plots
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 6))

# Flesch Reading Ease Score
ax1.bar(
    Flesch['labels'],
    Flesch['Mean Flesch Reading Ease Score'],
    color=['red', 'green', 'orange', 'yellow', 'navy'],
    edgecolor="black"
)
ax1.axhline(y=50, color="purple", linestyle='--', label='Fairly Difficult')
ax1.axhline(y=60, color="black", linestyle='-', label='Standard')
ax1.axhline(y=70, color='blue', linestyle=':', label='Fairly Easy')
ax1.set_title("Mean Flesch Reading Ease Score by Article Class")
ax1.set_xlabel('Article Class')
ax1.set_ylabel('Score')
ax1.legend(loc='lower right', title="Flesch Reading Ease Scores")

# Dale-Chall Readability Score
ax2.bar(
    Dale_Chall['labels'],
    Dale_Chall['Mean Dale-Chall Readability Score'],
    color=['orange', 'green', 'navy', 'yellow', 'red'],
    edgecolor="black"
)
ax2.axhline(y=7, color='purple', linestyle='--', label="Avg 9th-10th Grade Student")
ax2.axhline(y=8, color='black', linestyle='-', label="Avg 11th-12th Grade Student")
ax2.axhline(y=9, color='blue', linestyle=':', label="Avg College Student")
ax2.set_title('Mean Dale-Chall Readability Score by Article Class')
ax2.set_xlabel('Article Class')
ax2.set_ylabel('Score')
ax2.legend(loc='lower right', title="Dale-Chall Readability Scores")

# Overall Title
plt.suptitle('Reading Scores of BBC Articles', size=20)
plt.tight_layout()
plt.show()

# %%
encoder=LabelEncoder()
original_data['labels']=encoder.fit_transform(original_data['labels'])

# %%
# Split data into features (X) and labels (y)
X = original_data['text']
y = original_data['labels']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, shuffle=True, random_state=42
)

# Print shapes
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (1488,)
# X_test shape: (639,)
# y_train shape: (1488,)
# y_test shape: (639,)

# %%
# Download necessary resources (do this only once)
nltk.download('stopwords', quiet=True)
nltk.download('punkt', quiet=True)

# Set up stopwords and stemmer
stop_words = set(stopwords.words('english'))
stemmer = SnowballStemmer('english')

# Define preprocessing function
def preprocess(text):
    # Step 1: Remove non-alphabet characters and convert to lowercase
    text = re.sub("[^a-zA-Z]", " ", text)
    text = text.lower()

    # Step 2: Tokenize text
    try:
        from nltk.tokenize import word_tokenize
        words = word_tokenize(text)
    except LookupError:
        words = text.split()  # Fallback: split by whitespace if tokenization fails

    # Step 3: Remove stopwords and apply stemming
    words = [stemmer.stem(word) for word in words if word not in stop_words]

    # Step 4: Reassemble the words into a clean string
    return ' '.join(words)

# Apply preprocessing to train and test datasets
X_train = X_train.apply(preprocess)
X_test = X_test.apply(preprocess)

# %%
from gensim.models import Word2Vec

# Create a list of tokenized sentences
tokenized_sentences = [sentence.split() for sentence in X_train]

# Train Word2Vec model
w2v_model = Word2Vec(
    sentences=tokenized_sentences,
    vector_size=100,    # Dimensionality of the vectors
    window=5,           # Context window size
    min_count=2,        # Ignore words with total frequency lower than this
    workers=4,          # Number of CPU cores to use
    sg=1                # 1 for Skip-Gram; 0 for CBOW
)

# Save the model (optional)
#w2v_model.save("bbc_word2vec.model")

# %%
def vectorize(sentence):
    # Ensure sentence is a string
    sentence = str(sentence)
    words = sentence.split()

    # Get vectors for words present in the Word2Vec vocabulary
    word_vecs = [w2v_model.wv[word] for word in words if word in w2v_model.wv]

    # If no words are in the vocabulary, return a zero vector
    if len(word_vecs) == 0:
        return np.zeros(w2v_model.vector_size)  # VECTOR_SIZE = dimension of Word2Vec

    # Compute mean vector
    word_vecs = np.array(word_vecs)
    return word_vecs.mean(axis=0)

# %%
# Define vectorize function
def vectorize(sentence):
    # Ensure sentence is a string (flatten any array-like object)
    if isinstance(sentence, (list, np.ndarray)):
        sentence = " ".join(map(str, sentence))  # join list/array into a single string
    else:
        sentence = str(sentence)

    words = sentence.split()

    # Get vectors for words present in the Word2Vec vocabulary
    word_vecs = [w2v_model.wv[word] for word in words if word in w2v_model.wv]

    # If no words are in the vocabulary, return a zero vector
    if len(word_vecs) == 0:
        return np.zeros(w2v_model.vector_size)  # VECTOR_SIZE = dimension of Word2Vec

    # Compute mean vector
    word_vecs = np.array(word_vecs)
    return word_vecs.mean(axis=0)

# %%
# If X_train is a pandas Series
X_train = X_train.astype(str)

# If X_train is a numpy array of objects
X_train = np.array([str(x) for x in X_train])

# Same for X_test
X_test = np.array([str(x) for x in X_test])

# %%
X_train_vec = np.array([vectorize(sentence) for sentence in X_train])
X_test_vec = np.array([vectorize(sentence) for sentence in X_test])

print("Vectorized X_train shape:", X_train_vec.shape)
print("Vectorized X_test shape:", X_test_vec.shape)
# Out:
# Vectorized X_train shape: (1488, 100)
# Vectorized X_test shape: (639, 100)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# Logistic Regression
clf = LogisticRegression(random_state=42, max_iter=1000)  # Increase max_iter to ensure convergence
clf.fit(X_train_vec, y_train)

# Random Forest
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train_vec, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Logistic Regression predictions
y_pred_lr = clf.predict(X_test_vec)

print("📊 Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_lr))
print("🔖 Classification Report (Logistic Regression):\n", classification_report(y_test, y_pred_lr))

# Random Forest predictions
y_pred_rf = rf.predict(X_test_vec)

print("\n📊 Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
print("🔖 Classification Report (Random Forest):\n", classification_report(y_test, y_pred_rf))
# Out:
# 📊 Logistic Regression Accuracy: 0.23317683881064163
# 🔖 Classification Report (Logistic Regression):
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       165
#            1       0.00      0.00      0.00       114
#            2       0.00      0.00      0.00       106
#            3       0.23      1.00      0.38       149
#            4       0.00      0.00      0.00       105
#
#     accuracy                           0.23       639
#    macro avg       0.05      0.20      0.08       639
# weighted avg       0.05      0.23      0.09       639
#
#
# 📊 Random Forest Accuracy: 0.23317683881064163
# 🔖 Classification Report (Random Forest):
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       165
#            1       0.00      0.00      0.00       114
#            2       0.00      0.00      0.00       106
#            3       0.23      1.00      0.38       149
# ...

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score

# --- Random Forest Evaluation ---
y_pred_rf = rf.predict(X_test_vec)  # Use vectorized X_test

precision_rf = precision_score(y_test, y_pred_rf, average='macro')
recall_rf = recall_score(y_test, y_pred_rf, average='macro')
accuracy_rf = accuracy_score(y_test, y_pred_rf)

print('Random Forest -> Precision: {:.3f} / Recall: {:.3f} / Accuracy: {:.3f}'.format(
    precision_rf, recall_rf, accuracy_rf))

# --- Logistic Regression Evaluation ---
y_pred_lr = clf.predict(X_test_vec)  # Use vectorized X_test

precision_lr = precision_score(y_test, y_pred_lr, average='macro')
recall_lr = recall_score(y_test, y_pred_lr, average='macro')
accuracy_lr = accuracy_score(y_test, y_pred_lr)

print('Logistic Regression -> Precision: {:.3f} / Recall: {:.3f} / Accuracy: {:.3f}'.format(
    precision_lr, recall_lr, accuracy_lr))
# Out:
# Random Forest -> Precision: 0.047 / Recall: 0.200 / Accuracy: 0.233
# Logistic Regression -> Precision: 0.047 / Recall: 0.200 / Accuracy: 0.233

# %%
# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred_rf)  # y_test and y_pred_rf are numeric (encoded)

# Define class names (decoded from LabelEncoder)
class_names = encoder.inverse_transform(sorted(set(y_test)))

# Plot heat

# %%
# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred_rf)  # numeric encoded labels

# Decode class names from LabelEncoder
class_names = encoder.inverse_transform(sorted(set(y_test)))

# Plot heatmap
plt.figure(figsize=(6, 5))
ax = sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
ax.set_title('Confusion Matrix (Random Forest)', fontsize=16)
ax.set_xlabel("Predicted Labels", fontsize=12)
ax.set_ylabel("True Labels", fontsize=12)

# Set decoded class names for ticks
ax.xaxis.set_ticklabels(class_names, fontsize=10, rotation=45)
ax.yaxis.set_ticklabels(class_names, fontsize=10, rotation=0)

plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, accuracy_score

# Logistic Regression
clf = LogisticRegression(random_state=42, max_iter=1000)
clf.fit(X_train_vec, y_train)

# Random Forest
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train_vec, y_train)

# --- Random Forest Evaluation ---
y_pred_rf = rf.predict(X_test_vec)

precision_rf = precision_score(y_test, y_pred_rf, average='macro')
recall_rf = recall_score(y_test, y_pred_rf, average='macro')
accuracy_rf = accuracy_score(y_test, y_pred_rf)

print("Random Forest -> Precision: {:.3f} / Recall: {:.3f} / Accuracy: {:.3f}".format(
    precision_rf, recall_rf, accuracy_rf))

# --- Logistic Regression Evaluation ---
y_pred_lr = clf.predict(X_test_vec)

precision_lr = precision_score(y_test, y_pred_lr, average='macro')
recall_lr = recall_score(y_test, y_pred_lr, average='macro')
accuracy_lr = accuracy_score(y_test, y_pred_lr)

print("Logistic Regression -> Precision: {:.3f} / Recall: {:.3f} / Accuracy: {:.3f}".format(
    precision_lr, recall_lr, accuracy_lr))
# Out:
# Random Forest -> Precision: 0.047 / Recall: 0.200 / Accuracy: 0.233
# Logistic Regression -> Precision: 0.047 / Recall: 0.200 / Accuracy: 0.233

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Generate array of values for confusion matrix
cm = confusion_matrix(y_test, y_pred_rf, labels=rf.classes_)

# Plot heatmap
plt.figure(figsize=(6, 5))
ax = sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
ax.set_title('Confusion Matrix (Word2Vec + Random Forest)', fontsize=16)

# Set tick labels
ax.xaxis.set_ticklabels(['business', 'entertainment', 'politics', 'sport', 'tech'], fontsize=8, rotation=45)
ax.yaxis.set_ticklabels(['business', 'entertainment', 'politics', 'sport', 'tech'], fontsize=8, rotation=0)

ax.set_xlabel("Predicted", fontsize=12)
ax.set_ylabel("Actual", fontsize=12)

plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# Train Logistic Regression
clf_lr = LogisticRegression(random_state=42, max_iter=1000)
clf_lr.fit(X_train_vec, y_train)

# Train Random Forest
clf_rf = RandomForestClassifier(random_state=42)
clf_rf.fit(X_train_vec, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
import joblib

# Save Word2Vec model
w2v_model.save("word2vec_model.bin")

# Save LabelEncoder
joblib.dump(encoder, "label_encoder.pkl")

# Save Logistic Regression and Random Forest
joblib.dump(clf_lr, "logistic_regression.pkl")
joblib.dump(clf_rf, "random_forest.pkl")
# Out:
# ['random_forest.pkl']

# %%
from google.colab import files

# Download each file
files.download("word2vec_model.bin")
files.download("label_encoder.pkl")
files.download("logistic_regression.pkl")
files.download("random_forest.pkl")

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-480f95ca-b3f9-40c5-9029-83709d6f30b2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-480f95ca-b3f9-40c5-9029-83709d6f30b2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1470f9d7-fd39-4a24-bec7-e196a1e6b06a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1470f9d7-fd39-4a24-bec7-e196a1e6b06a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2deb0cf7-5e14-4419-84e2-f85cf2c433b0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2deb0cf7-5e14-4419-84e2-f85cf2c433b0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7a40f7dc-4de7-4f6d-8932-f4505d7ed5ef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7a40f7dc-4de7-4f6d-8932-f4505d7ed5ef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a9e1ce44-b64d-4531-a805-74fb36e1d293" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a9e1ce44-b64d-4531-a805-74fb36e1d293">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install streamlit pyngrok
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 97.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 128.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 8.1 MB/s eta 0:00:00
# ...

# %%
from pyngrok import ngrok

# Replace 'your-token-here' with your actual authtoken
ngrok.set_auth_token("2vb6uRwMyTdJZ4hzGTxZTZMpUc2_7qhN6heNm54WjVsdpK51P")

# %%
from pyngrok import ngrok
import subprocess
import time

# Clean up existing tunnels before starting
for tunnel in ngrok.get_tunnels():
    print(f"Disconnecting tunnel: {tunnel.public_url}")
    ngrok.disconnect(tunnel.public_url)

# Run Streamlit app in the background
process = subprocess.Popen(["streamlit", "run", "app.py"])

# Wait for Streamlit to start
time.sleep(10)

# Create a new tunnel
public_url = ngrok.connect(8501)
print("🔗 Streamlit app is live at:", public_url)

# Optionally, wait for the Streamlit process to end
process.wait()
# Out:
# WARNING:pyngrok.process.ngrok:t=2025-07-11T15:08:30+0000 lvl=warn msg="Stopping forwarder" name=http-8501-1e3e2af5-d662-4035-9b4f-63cfb3848b92 acceptErr="failed to accept connection: Listener closed"
# WARNING:pyngrok.process.ngrok:t=2025-07-11T15:08:30+0000 lvl=warn msg="Stopping forwarder" name=http-8501-d274fb2a-4de1-41d1-98d6-f53c6f7d214d acceptErr="failed to accept connection: Listener closed"
# WARNING:pyngrok.process.ngrok:t=2025-07-11T15:08:31+0000 lvl=warn msg="Stopping forwarder" name=http-8501-355db232-6d6c-48e7-ab38-e02d4933fbbf acceptErr="failed to accept connection: Listener closed"
# Disconnecting tunnel: https://20080e59055a.ngrok-free.app
# Disconnecting tunnel: https://c476d4c74d5d.ngrok-free.app
# Disconnecting tunnel: https://f506b8139523.ngrok-free.app
# 🔗 Streamlit app is live at: NgrokTunnel: "https://338f136655e4.ngrok-free.app" -> "http://localhost:8501"
# 2
